# %%
import os
import pandas as pd
import json

# Set the path to the folder containing the JSON files
results_folder = "./results"

# Initialize an empty list to store the individual DataFrames
dataframes = []

# Iterate over all files in the results folder
for file in os.listdir(results_folder):
    # Check if the file is a JSON file
    if file.endswith(".json"):
        # Load the JSON file
        file_path = os.path.join(results_folder, file)
        with open(file_path, "r") as f:
            data = json.load(f)
        
        # Convert the JSON data to a Pandas DataFrame and add it to the list
        df = pd.DataFrame(data, index=[0])
        #df = pd.json_normalize(data)
        dataframes.append(df)

# Combine all individual DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df
# Out:
#                     date cdevice        qdevice shots  model_id    time_taken  \
# 0   05/07/2023, 11:23:10     cpu  default.qubit  None        11    951.049141
# 1   05/07/2023, 11:40:07     cpu  default.qubit  None        12   1016.314283
# 2   05/07/2023, 11:45:33     cpu  default.qubit  None        13    325.954535
# 3   05/07/2023, 10:45:00     cpu  default.qubit  None         8    137.676228
# 4   04/07/2023, 16:18:22     cpu  default.qubit  None         2     80.850748
# 5   05/07/2023, 10:50:21     cpu  default.qubit  None         9    321.068830
# 6   05/07/2023, 10:40:45     cpu  default.qubit  None         6    121.995460
# 7   04/07/2023, 16:22:32     cpu  default.qubit  None         5     78.651854
# 8   04/07/2023, 16:33:53     cpu  default.qubit  None         9    301.137777
# 9   05/07/2023, 10:33:42     cpu  default.qubit  None         1     34.393936
# 10  05/07/2023, 10:36:45     cpu  default.qubit  None         3    112.086471
# 11  04/07/2023, 16:21:13     cpu  default.qubit  None         4     46.111066
# 12  04/07/2023, 16:28:51     cpu  default.qubit  None         8    130.506435
# 13  04/07/2023, 16:17:01     cpu  default.qubit  None         1     40.933122
# 14  04/07/2023, 16:20:27     cpu  default.qubit  None         3    124.610939
# 15  04/07/2023, 16:24:40     cpu  default.qubit  None         6    128.381488
# 16  04/07/2023, 16:26:41     cpu  default.qubit  None         7    120.822780
# 17  05/07/2023, 10:34:53     cpu  default.qubit  None         2     71.575568
# 18  05/07/2023, 19:35:51     cpu  default.qubit  None        17  10371.709424
# 19  05/07/2023, 10:42:42     cpu  default.qubit  None         7    116.597191
# 20  05/07/2023, 10:38:43     cpu  default.qubit  None         5     78.692806
# 21  05/07/2023, 12:40:27     cpu  default.qubit  None        14   3293.889144
# 22  05/07/2023, 11:07:19     cpu  default.qubit  None        10   1017.992400
# 23  05/07/2023, 16:42:59     cpu  default.qubit  None        16  11119.881814
# 24  05/07/2023, 13:37:39     cpu  default.qubit  None        15   3431.572277
# 25  05/07/2023, 10:37:25     cpu  default.qubit  None         4     39.405962
#
#     num_data_samples  num_parameter_samples  gamma  seed      effdim
# 0                 50                     10    1.0     0   38.140878
# 1                 50                     10    1.0     0   31.765257
# 2                 50                     10    1.0     0   13.700081
# 3                 50                     10    1.0     0   11.182495
# 4                 50                     10    1.0     0   -5.887384
# 5                 50                     10    1.0     0   13.700081
# 6                 50                     10    1.0     0    8.463462
# 7                 50                     10    1.0     0   -6.564256
# 8                 50                     10    1.0     0  -13.717376
# 9                 50                     10    1.0     0    3.588496
# 10                50                     10    1.0     0    7.563165
# 11                50                     10    1.0     0   -3.546722
# 12                50                     10    1.0     0  -10.824522
# 13                50                     10    1.0     0   -3.574567
# 14                50                     10    1.0     0   -8.059359
# 15                50                     10    1.0     0   -8.796324
# 16                50                     10    1.0     0   -9.527500
# 17                50                     10    1.0     0    5.623127
# 18                50                     10    1.0     0  101.480515
# 19                50                     10    1.0     0    9.459183
# 20                50                     10    1.0     0    6.504219
# 21                50                     10    1.0     0   34.384479
# 22                50                     10    1.0     0   31.765257
# 23                50                     10    1.0     0  101.480515
# 24                50                     10    1.0     0   34.384479
# 25                50                     10    1.0     0    3.549334
