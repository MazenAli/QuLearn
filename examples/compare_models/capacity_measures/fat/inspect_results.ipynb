# %%
import os
import pandas as pd
import json

# Set the path to the folder containing the JSON files
results_folder = "./results"

# Initialize an empty list to store the individual DataFrames
dataframes = []

# Iterate over all files in the results folder
for file in os.listdir(results_folder):
    # Check if the file is a JSON file
    if file.endswith(".json"):
        # Load the JSON file
        file_path = os.path.join(results_folder, file)
        with open(file_path, "r") as f:
            data = json.load(f)
        
        # Convert the JSON data to a Pandas DataFrame and add it to the list
        df = pd.DataFrame(data, index=[0])
        #df = pd.json_normalize(data)
        dataframes.append(df)

# Combine all individual DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df
# Out:
#                     date cdevice          qdevice shots  model_id  \
# 0   03/07/2023, 14:11:12     cpu  lightning.qubit  None         4
# 1   03/07/2023, 23:33:49     cpu  lightning.qubit  None        18
# 2   03/07/2023, 14:11:22     cpu  lightning.qubit  None         5
# 3   03/07/2023, 14:20:25     cpu  lightning.qubit  None        14
# 4   03/07/2023, 14:18:31     cpu  lightning.qubit  None        12
# 5   03/07/2023, 14:36:09     cpu  lightning.qubit  None        16
# 6   03/07/2023, 14:10:43     cpu  lightning.qubit  None         3
# 7   03/07/2023, 14:14:39     cpu  lightning.qubit  None        10
# 8   03/07/2023, 14:20:03     cpu  lightning.qubit  None        13
# 9   03/07/2023, 14:13:27     cpu  lightning.qubit  None         8
# 10  03/07/2023, 14:15:04     cpu  lightning.qubit  None        11
# 11  03/07/2023, 14:12:55     cpu  lightning.qubit  None         6
# 12  03/07/2023, 14:09:44     cpu  lightning.qubit  None         1
# 13  03/07/2023, 14:09:57     cpu  lightning.qubit  None         2
# 14  03/07/2023, 14:13:12     cpu  lightning.qubit  None         7
# 15  03/07/2023, 14:34:56     cpu  lightning.qubit  None        15
# 16  03/07/2023, 23:31:36     cpu  lightning.qubit  None        17
# 17  03/07/2023, 14:14:07     cpu  lightning.qubit  None         9
#
#       time_taken  dmin  dmax  dstep  Sb  Sr   lr  num_epochs  batch_size  \
# 0      28.386938     1   100      1  10   5  0.1         200          25
# 1     133.127885     1   100      1  10   5  0.1         200          25
# 2      10.272866     1   100      1  10   5  0.1         200          25
# 3      21.898895     1   100      1  10   5  0.1         200          25
# 4     206.361867     1   100      1  10   5  0.1         200          25
# 5      72.280652     1   100      1  10   5  0.1         200          25
# 6      46.534101     1   100      1  10   5  0.1         200          25
# 7      32.645211     1   100      1  10   5  0.1         200          25
# 8      91.878196     1   100      1  10   5  0.1         200          25
# 9      15.695915     1   100      1  10   5  0.1         200          25
# 10     24.957624     1   100      1  10   5  0.1         200          25
# 11     93.325928     1   100      1  10   5  0.1         200          25
# 12     28.242922     1   100      1  10   5  0.1         200          25
# 13     12.777067     1   100      1  10   5  0.1         200          25
# 14     16.338031     1   100      1  10   5  0.1         200          25
# 15    871.770859     1   100      1  10   5  0.1         200          25
# 16  32127.481210     1   100      1  10   5  0.1         200          25
# 17     39.373118     1   100      1  10   5  0.1         200          25
#
#     seed  dimension
# 0      0          1
# 1      0          1
# 2      0          1
# 3      0          1
# 4      0          2
# 5      0          1
# 6      0          1
# 7      0          1
# 8      0          2
# 9      0          1
# 10     0          1
# 11     0          2
# 12     0          1
# 13     0          1
# 14     0          1
# 15     0          3
# 16     0         25
# 17     0          1
