# %%
import os
import pandas as pd
import json

# Set the path to the folder containing the JSON files
results_folder = "./results"

# Initialize an empty list to store the individual DataFrames
dataframes = []

# Iterate over all files in the results folder
for file in os.listdir(results_folder):
    # Check if the file is a JSON file
    if file.endswith(".json"):
        # Load the JSON file
        file_path = os.path.join(results_folder, file)
        with open(file_path, "r") as f:
            data = json.load(f)
        
        # Convert the JSON data to a Pandas DataFrame and add it to the list
        df = pd.DataFrame(data, index=[0])
        #df = pd.json_normalize(data)
        dataframes.append(df)

# Combine all individual DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df
# Out:
#                    date cdevice        qdevice shots  model_id    time_taken  \
# 0  19/09/2023, 03:06:04     cpu  default.qubit  None         5   2578.665899
# 1  18/09/2023, 22:13:40     cpu  default.qubit  None         2    809.473552
# 2  18/09/2023, 22:00:10     cpu  default.qubit  None         1    614.442974
# 3  19/09/2023, 02:23:05     cpu  default.qubit  None         4  11607.977457
# 4  18/09/2023, 23:09:37     cpu  default.qubit  None         3   3356.978693
# 5  19/09/2023, 03:51:27     cpu  default.qubit  None         6   2723.058248
#
#    dmin  dmax  dstep  Sb  Sr   lr  num_epochs  batch_size  seed  dimension
# 0     1   100      1  10   5  0.1         200          25     0          5
# 1     1   100      1  10   5  0.1         200          25     0          3
# 2     1   100      1  10   5  0.1         200          25     0          4
# 3     1   100      1  10   5  0.1         200          25     0         10
# 4     1   100      1  10   5  0.1         200          25     0          5
# 5     1   100      1  10   5  0.1         200          25     0          5
