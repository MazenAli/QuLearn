# %%
import os
import pandas as pd
import json

# Set the path to the folder containing the JSON files
results_folder = "./results"

# Initialize an empty list to store the individual DataFrames
dataframes = []

# Iterate over all files in the results folder
for file in os.listdir(results_folder):
    # Check if the file is a JSON file
    if file.endswith(".json"):
        # Load the JSON file
        file_path = os.path.join(results_folder, file)
        with open(file_path, "r") as f:
            data = json.load(f)
        
        # Convert the JSON data to a Pandas DataFrame and add it to the list
        df = pd.DataFrame(data, index=[0])
        #df = pd.json_normalize(data)
        dataframes.append(df)

# Combine all individual DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df
# Out:
#                     date cdevice        qdevice shots  model_id    time_taken  \
# 0   05/07/2023, 16:30:35     cpu  default.qubit  None        17  55855.511951
# 1   04/07/2023, 13:02:50     cpu  default.qubit  None         9    695.237398
# 2   04/07/2023, 18:38:11     cpu  default.qubit  None        12   4401.783404
# 3   04/07/2023, 11:29:20     cpu  default.qubit  None         3   1005.776602
# 4   04/07/2023, 12:51:15     cpu  default.qubit  None         8   1578.380628
# 5   04/07/2023, 11:49:04     cpu  default.qubit  None         5    848.859434
# 6   04/07/2023, 22:24:45     cpu  default.qubit  None        15  11530.237046
# 7   04/07/2023, 12:24:57     cpu  default.qubit  None         7   1036.760117
# 8   04/07/2023, 11:34:55     cpu  default.qubit  None         4    335.052397
# 9   04/07/2023, 11:04:29     cpu  default.qubit  None         1    334.084517
# 10  04/07/2023, 13:49:28     cpu  default.qubit  None        10   2797.734247
# 11  04/07/2023, 19:12:35     cpu  default.qubit  None        14    686.683712
# 12  04/07/2023, 17:24:49     cpu  default.qubit  None        11  12920.731336
# 13  04/07/2023, 12:07:40     cpu  default.qubit  None         6   1116.027382
# 14  04/07/2023, 11:12:34     cpu  default.qubit  None         2    485.005364
# 15  05/07/2023, 00:59:39     cpu  default.qubit  None        16   9294.521245
# 16  04/07/2023, 19:01:08     cpu  default.qubit  None        13   1377.432775
#
#     Nmin  Nmax  Nstep  num_samples   lr  num_epochs  batch_size  seed  \
# 0      1   100      1           20  0.1         200          25     0
# 1      1   100      1           20  0.1         200          25     0
# 2      1   100      1           20  0.1         200          25     0
# 3      1   100      1           20  0.1         200          25     0
# 4      1   100      1           20  0.1         200          25     0
# 5      1   100      1           20  0.1         200          25     0
# 6      1   100      1           20  0.1         200          25     0
# 7      1   100      1           20  0.1         200          25     0
# 8      1   100      1           20  0.1         200          25     0
# 9      1   100      1           20  0.1         200          25     0
# 10     1   100      1           20  0.1         200          25     0
# 11     1   100      1           20  0.1         200          25     0
# 12     1   100      1           20  0.1         200          25     0
# 13     1   100      1           20  0.1         200          25     0
# 14     1   100      1           20  0.1         200          25     0
# 15     1   100      1           20  0.1         200          25     0
# 16     1   100      1           20  0.1         200          25     0
#
#     capacity
# 0        150
# 1         30
# 2         44
# 3         36
# 4         48
# 5         18
# 6         84
# 7         33
# 8         24
# 9          8
# 10        42
# 11        15
# 12       104
# 13        30
# 14        28
# 15        60
# 16        42
