# %%
import os
import pandas as pd
import json

# Set the path to the folder containing the JSON files
results_folder = "./results"

# Initialize an empty list to store the individual DataFrames
dataframes = []

# Iterate over all files in the results folder
for file in os.listdir(results_folder):
    # Check if the file is a JSON file
    if file.endswith(".json"):
        # Load the JSON file
        file_path = os.path.join(results_folder, file)
        with open(file_path, "r") as f:
            data = json.load(f)
        
        # Convert the JSON data to a Pandas DataFrame and add it to the list
        df = pd.DataFrame(data, index=[0])
        #df = pd.json_normalize(data)
        dataframes.append(df)

# Combine all individual DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df
# Out:
#                     date cdevice        qdevice shots  model_id    time_taken  \
# 0   04/07/2023, 19:48:51     cpu  default.qubit  None         1  10033.450456
# 1   05/07/2023, 14:07:31     cpu  default.qubit  None         5  18685.176556
# 2   06/07/2023, 10:09:10     cpu  default.qubit  None         8  25844.458812
# 3   08/07/2023, 03:46:18     cpu  default.qubit  None        11  61840.999266
# 4   05/07/2023, 06:00:36     cpu  default.qubit  None         3  21353.118413
# 5   05/07/2023, 00:04:43     cpu  default.qubit  None         2  15352.528432
# 6   06/07/2023, 02:58:25     cpu  default.qubit  None         7  21372.964258
# 7   07/07/2023, 10:35:37     cpu  default.qubit  None        10  62488.369080
# 8   05/07/2023, 08:56:06     cpu  default.qubit  None         4  10529.145530
# 9   05/07/2023, 21:02:12     cpu  default.qubit  None         6  24881.425332
# 10  06/07/2023, 17:14:09     cpu  default.qubit  None         9  25499.336107
#
#      m  num_data_samples  num_sigma_sample   lr  num_epochs  batch_size  seed  \
# 0   50                10                10  0.1         200          25     0
# 1   50                10                10  0.1         200          25     0
# 2   50                10                10  0.1         200          25     0
# 3   50                10                10  0.1         200          25     0
# 4   50                10                10  0.1         200          25     0
# 5   50                10                10  0.1         200          25     0
# 6   50                10                10  0.1         200          25     0
# 7   50                10                10  0.1         200          25     0
# 8   50                10                10  0.1         200          25     0
# 9   50                10                10  0.1         200          25     0
# 10  50                10                10  0.1         200          25     0
#
#     rademacher
# 0   101.991920
# 1   180.564529
# 2   252.808456
# 3   386.564331
# 4   188.102173
# 5   155.118622
# 6   214.170181
# 7   273.235535
# 8   107.209381
# 9   212.573120
# 10  144.485992
