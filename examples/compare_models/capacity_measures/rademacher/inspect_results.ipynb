# %%
import os
import pandas as pd
import json

# Set the path to the folder containing the JSON files
results_folder = "./results"

# Initialize an empty list to store the individual DataFrames
dataframes = []

# Iterate over all files in the results folder
for file in os.listdir(results_folder):
    # Check if the file is a JSON file
    if file.endswith(".json"):
        # Load the JSON file
        file_path = os.path.join(results_folder, file)
        with open(file_path, "r") as f:
            data = json.load(f)
        
        # Convert the JSON data to a Pandas DataFrame and add it to the list
        df = pd.DataFrame(data, index=[0])
        #df = pd.json_normalize(data)
        dataframes.append(df)

# Combine all individual DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df
# Out:
#                    date cdevice        qdevice shots  model_id    time_taken  \
# 0  19/09/2023, 23:45:58     cpu  default.qubit  None         2  68052.389424
# 1  21/09/2023, 00:22:49     cpu  default.qubit  None         3  88610.394566
# 2  22/09/2023, 01:39:19     cpu  default.qubit  None         4  90990.305009
# 3  22/09/2023, 21:34:42     cpu  default.qubit  None         5  71722.738021
# 4  19/09/2023, 04:51:46     cpu  default.qubit  None         1  25226.936519
# 5  23/09/2023, 18:29:41     cpu  default.qubit  None         6  75298.862318
#
#     m  num_data_samples  num_sigma_sample   lr  num_epochs  batch_size  seed  \
# 0  50                10                10  0.1         200          25     0
# 1  50                10                10  0.1         200          25     0
# 2  50                10                10  0.1         200          25     0
# 3  50                10                10  0.1         200          25     0
# 4  50                10                10  0.1         200          25     0
# 5  50                10                10  0.1         200          25     0
#
#    rademacher
# 0  184.765182
# 1  705.759277
# 2  817.896667
# 3  250.112976
# 4  239.321899
# 5  431.636597
